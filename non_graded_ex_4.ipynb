# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time

card_deck = [
    {"Name": "Diablo", "Health": 100, "Attack": 90, "Defense": 60},
    {"Name": "Medusa", "Health": 100, "Attack": 70, "Defense": 70},
    {"Name": "Jester", "Health": 120, "Attack": 60, "Defense": 90},
    {"Name": "Troll", "Health": 150, "Attack": 40, "Defense": 94},
    {"Name": "Specter", "Health": 100, "Attack": 70, "Defense": 70},
    {"Name": "Mist", "Health": 100, "Attack": 75, "Defense": 65},
    {"Name": "Savage", "Health": 100, "Attack": 90, "Defense": 50},
    {"Name": "Marauder", "Health": 100, "Attack": 85, "Defense": 50},
    {"Name": "Wimp", "Health": 110, "Attack": 40, "Defense": 85},
    {"Name": "Sorcerer", "Health": 100, "Attack": 70, "Defense": 55},
]

deck_size = 5
player_deck = random.sample(card_deck, deck_size)
opponent_deck = random.sample(card_deck, deck_size)

def display_deck(deck, owner="Player"):
    print(f"\n{owner}'s Deck:")
    for i, card in enumerate(deck):
        print(f"{i+1}. {card['Name']} - Health: {card['Health']}, Attack: {card['Attack']}, Defense: {card['Defense']}")

def attack(player_card, opponent_card):
    print(f"\n{player_card['Name']} attacks {opponent_card['Name']}!")

    if player_card["Attack"] > opponent_card["Health"]:
     
        print(f"{player_card['Name']}'s attack is too strong for {opponent_card['Name']}! {opponent_card['Name']} is defeated!")
        return True

    if player_card["Attack"] >= opponent_card["Defense"]:
        remaining_attack = player_card["Attack"] - opponent_card["Defense"]
        opponent_card["Defense"] = 0
        opponent_card["Health"] -= remaining_attack
        print(f"{opponent_card['Name']}'s defense is broken! Remaining attack reduces health by {remaining_attack}.")
    else:
        opponent_card["Defense"] -= player_card["Attack"]
        print(f"{opponent_card['Name']}'s defense absorbs the attack. New defense value: {opponent_card['Defense']}")

    if opponent_card["Health"] <= 0:
        print(f"{opponent_card['Name']} has been defeated!")
        return True
    
    return False

while player_deck and opponent_deck:

    print("\n=== Player's Turn ===")
    display_deck(player_deck)

    opponent_card = random.choice(opponent_deck)
    print(f"\nOpponent's card is: {opponent_card['Name']} - Health: {opponent_card['Health']}, Attack: {opponent_card['Attack']}, Defense: {opponent_card['Defense']}")
    
    player_choice = int(input("\nChoose a card to play (1-5): ")) - 1
    player_card = player_deck[player_choice]

    if attack(player_card, opponent_card):
        opponent_deck.remove(opponent_card)
    time.sleep(2)

    if not opponent_deck:
        print("\nCongratulations! You have defeated all of the opponent's cards. You win!")
        break

    print("\n=== Opponent's Turn ===")
    time.sleep(2)

    opponent_card = random.choice(opponent_deck)
    print(f"\nOpponent chooses: {opponent_card['Name']} - Health: {opponent_card['Health']}, Attack: {opponent_card['Attack']}, Defense: {opponent_card['Defense']}")

    player_card = random.choice(player_deck)
    print(f"Your card is: {player_card['Name']} - Health: {player_card['Health']}, Attack: {player_card['Attack']}, Defense: {player_card['Defense']}")

    if attack(opponent_card, player_card):
        player_deck.remove(player_card)
    time.sleep(2)

    if not player_deck:
        print("\nAll of your cards have been defeated. The opponent wins!")
        break
# Out:
# === Player's Turn ===
#
# Player's Deck:
# 1. Mist - Health: 100, Attack: 75, Defense: 65
# 2. Diablo - Health: 100, Attack: 90, Defense: 60
# 3. Jester - Health: 120, Attack: 60, Defense: 90
# 4. Medusa - Health: 100, Attack: 70, Defense: 70
# 5. Troll - Health: 150, Attack: 40, Defense: 94
#
# Opponent's card is: Diablo - Health: 100, Attack: 90, Defense: 60
#
# Mist attacks Diablo!
# Diablo's defense is broken! Remaining attack reduces health by 15.
#
# === Opponent's Turn ===
#
# Opponent chooses: Jester - Health: 120, Attack: 60, Defense: 90
# Your card is: Troll - Health: 150, Attack: 40, Defense: 94
#
# Jester attacks Troll!
# Troll's defense absorbs the attack. New defense value: 34
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Mist - Health: 100, Attack: 75, Defense: 65
# 2. Diablo - Health: 85, Attack: 90, Defense: 0
# 3. Jester - Health: 120, Attack: 60, Defense: 90
# 4. Medusa - Health: 100, Attack: 70, Defense: 70
# 5. Troll - Health: 150, Attack: 40, Defense: 34
#
# Opponent's card is: Specter - Health: 100, Attack: 70, Defense: 70
#
# Mist attacks Specter!
# Specter's defense is broken! Remaining attack reduces health by 5.
#
# === Opponent's Turn ===
#
# Opponent chooses: Jester - Health: 120, Attack: 60, Defense: 90
# Your card is: Mist - Health: 100, Attack: 75, Defense: 65
#
# Jester attacks Mist!
# Mist's defense absorbs the attack. New defense value: 5
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Mist - Health: 100, Attack: 75, Defense: 5
# 2. Diablo - Health: 85, Attack: 90, Defense: 0
# 3. Jester - Health: 120, Attack: 60, Defense: 90
# 4. Medusa - Health: 100, Attack: 70, Defense: 70
# 5. Troll - Health: 150, Attack: 40, Defense: 34
#
# Opponent's card is: Specter - Health: 95, Attack: 70, Defense: 0
#
# Mist attacks Specter!
# Specter's defense is broken! Remaining attack reduces health by 75.
#
# === Opponent's Turn ===
#
# Opponent chooses: Marauder - Health: 100, Attack: 85, Defense: 50
# Your card is: Mist - Health: 100, Attack: 75, Defense: 5
#
# Marauder attacks Mist!
# Mist's defense is broken! Remaining attack reduces health by 80.
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Mist - Health: 20, Attack: 75, Defense: 0
# 2. Diablo - Health: 85, Attack: 90, Defense: 0
# 3. Jester - Health: 120, Attack: 60, Defense: 90
# 4. Medusa - Health: 100, Attack: 70, Defense: 70
# 5. Troll - Health: 150, Attack: 40, Defense: 34
#
# Opponent's card is: Diablo - Health: 85, Attack: 90, Defense: 0
#
# Diablo attacks Diablo!
# Diablo's attack is too strong for Diablo! Diablo is defeated!
#
# === Opponent's Turn ===
#
# Opponent chooses: Troll - Health: 150, Attack: 40, Defense: 34
# Your card is: Diablo - Health: 85, Attack: 90, Defense: 0
#
# Troll attacks Diablo!
# Diablo's defense is broken! Remaining attack reduces health by 40.
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Mist - Health: 20, Attack: 75, Defense: 0
# 2. Diablo - Health: 45, Attack: 90, Defense: 0
# 3. Jester - Health: 120, Attack: 60, Defense: 90
# 4. Medusa - Health: 100, Attack: 70, Defense: 70
# 5. Troll - Health: 150, Attack: 40, Defense: 34
#
# Opponent's card is: Troll - Health: 150, Attack: 40, Defense: 34
#
# Mist attacks Troll!
# Troll's defense is broken! Remaining attack reduces health by 41.
#
# === Opponent's Turn ===
#
# Opponent chooses: Troll - Health: 109, Attack: 40, Defense: 0
# Your card is: Troll - Health: 109, Attack: 40, Defense: 0
#
# Troll attacks Troll!
# Troll's defense is broken! Remaining attack reduces health by 40.
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Mist - Health: 20, Attack: 75, Defense: 0
# 2. Diablo - Health: 45, Attack: 90, Defense: 0
# 3. Jester - Health: 120, Attack: 60, Defense: 90
# 4. Medusa - Health: 100, Attack: 70, Defense: 70
# 5. Troll - Health: 69, Attack: 40, Defense: 0
#
# Opponent's card is: Specter - Health: 20, Attack: 70, Defense: 0
#
# Mist attacks Specter!
# Mist's attack is too strong for Specter! Specter is defeated!
#
# === Opponent's Turn ===
#
# Opponent chooses: Marauder - Health: 100, Attack: 85, Defense: 50
# Your card is: Troll - Health: 69, Attack: 40, Defense: 0
#
# Marauder attacks Troll!
# Marauder's attack is too strong for Troll! Troll is defeated!
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Mist - Health: 20, Attack: 75, Defense: 0
# 2. Diablo - Health: 45, Attack: 90, Defense: 0
# 3. Jester - Health: 120, Attack: 60, Defense: 90
# 4. Medusa - Health: 100, Attack: 70, Defense: 70
#
# Opponent's card is: Jester - Health: 120, Attack: 60, Defense: 90
#
# Mist attacks Jester!
# Jester's defense absorbs the attack. New defense value: 15
#
# === Opponent's Turn ===
#
# Opponent chooses: Marauder - Health: 100, Attack: 85, Defense: 50
# Your card is: Jester - Health: 120, Attack: 60, Defense: 15
#
# Marauder attacks Jester!
# Jester's defense is broken! Remaining attack reduces health by 70.
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Mist - Health: 20, Attack: 75, Defense: 0
# 2. Diablo - Health: 45, Attack: 90, Defense: 0
# 3. Jester - Health: 50, Attack: 60, Defense: 0
# 4. Medusa - Health: 100, Attack: 70, Defense: 70
#
# Opponent's card is: Marauder - Health: 100, Attack: 85, Defense: 50
#
# Mist attacks Marauder!
# Marauder's defense is broken! Remaining attack reduces health by 25.
#
# === Opponent's Turn ===
#
# Opponent chooses: Jester - Health: 50, Attack: 60, Defense: 0
# Your card is: Diablo - Health: 45, Attack: 90, Defense: 0
#
# Jester attacks Diablo!
# Jester's attack is too strong for Diablo! Diablo is defeated!
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Mist - Health: 20, Attack: 75, Defense: 0
# 2. Jester - Health: 50, Attack: 60, Defense: 0
# 3. Medusa - Health: 100, Attack: 70, Defense: 70
#
# Opponent's card is: Troll - Health: 69, Attack: 40, Defense: 0
#
# Medusa attacks Troll!
# Medusa's attack is too strong for Troll! Troll is defeated!
#
# === Opponent's Turn ===
#
# Opponent chooses: Marauder - Health: 75, Attack: 85, Defense: 0
# Your card is: Jester - Health: 50, Attack: 60, Defense: 0
#
# Marauder attacks Jester!
# Marauder's attack is too strong for Jester! Jester is defeated!
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Mist - Health: 20, Attack: 75, Defense: 0
# 2. Medusa - Health: 100, Attack: 70, Defense: 70
#
# Opponent's card is: Jester - Health: 50, Attack: 60, Defense: 0
#
# Medusa attacks Jester!
# Medusa's attack is too strong for Jester! Jester is defeated!
#
# === Opponent's Turn ===
#
# Opponent chooses: Marauder - Health: 75, Attack: 85, Defense: 0
# Your card is: Mist - Health: 20, Attack: 75, Defense: 0
#
# Marauder attacks Mist!
# Marauder's attack is too strong for Mist! Mist is defeated!
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Medusa - Health: 100, Attack: 70, Defense: 70
#
# Opponent's card is: Marauder - Health: 75, Attack: 85, Defense: 0
#
# Medusa attacks Marauder!
# Marauder's defense is broken! Remaining attack reduces health by 70.
#
# === Opponent's Turn ===
#
# Opponent chooses: Marauder - Health: 5, Attack: 85, Defense: 0
# Your card is: Medusa - Health: 100, Attack: 70, Defense: 70
#
# Marauder attacks Medusa!
# Medusa's defense is broken! Remaining attack reduces health by 15.
#
# === Player's Turn ===
#
# Player's Deck:
# 1. Medusa - Health: 85, Attack: 70, Defense: 0
#
# Opponent's card is: Marauder - Health: 5, Attack: 85, Defense: 0
#
# Medusa attacks Marauder!
# Medusa's attack is too strong for Marauder! Marauder is defeated!
#
# Congratulations! You have defeated all of the opponent's cards. You win!
